# %%
import numpy as np

# %%
np.__version__
# Out:
# '2.4.6'

# %%
np.array([2,3,4])
# Out:
# array([2, 3, 4])

# %%
print(np.array([2,3,4]))
# Out:
# [2 3 4]

# %%
import numpy as np

camera_position = np.array([1.0, 2.0, 0.5])

print(camera_position)
# Out:
# [1.  2.  0.5]
